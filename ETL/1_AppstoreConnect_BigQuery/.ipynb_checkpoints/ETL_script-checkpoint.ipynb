# %%
import os
import numpy as np
import pandas as pd
import re
from math import isnan
from datetime import datetime
#
from google.api_core import exceptions

# %%
# Import custom classes for load and transform
from Reporter import Reporter
from Preprocessing import Preprocessing

# %% [markdown]
# Reporter - дополнительный класс, инцилизируется с помощью
# - **reporter_parms**
#   `start_date`, `end_date`  - интервал, в котором скачиваются отчеты
#   `name` - название типа отчетов \\ TODO: чтобы был листом
#   `id` - идентификатор МП в appstore
#   `path_dist` - путь, куда грузятся отчеты (для удобства совпадает с base_dir)
#
# После инцилизации есть 2 метода:
# - extract():
# Реализует выгрузку отчетов, согласно тому, как это было задано параметрами, можно проверить методом .show()
# - update_dates(dates):
# Обновляет даты в конфигурации
#
# dates - формата list ([]), в котором даты должны быть 'YYYYMMDD'
# Например dates = ['20231231','20240101']
#
# - show():
#
# Preprocessing - дополнительный класс для обработки полей в отчетах от AppStore Connect
#
# # Параметры выгрузки
# - **base_dir**
# Путь, в котором будут сложены отчеты (.csv)
# - **appstore_id**
# Идентификатор МП в appstore
# - **reporter_parms**
#   `start_date`, `end_date`  - интервал, в котором скачиваются отчеты
#   `name` - название типа отчетов \\ TODO: чтобы был листом
#   `id` - идентификатор МП в appstore
#   `path_dist` - путь, куда грузятся отчеты (для удобства совпадает с base_dir)
# - **project_id**
#  Название проекта в Big Query
# - **dataset_id**
#  Название датасета внутри проекта
#
# - **credentials_json**
#  Путь к json (для аутентификации в сервисах GCP)

# %%
# Path in OS for download with PC owner script
base_dir = 'C:\\Users\\PC\\Desktop\\Notebooks\\datasets\\Apple Appstore connect data'
# AppStore identifies each mobile app as id, for example 12345678 (size = 8)
appstore_id = 89936618
reporter_parms = {'start_date': '2024/03/22',
                  'end_date': '2024/03/25',
                  'name': ' ',
                  'id': appstore_id,
                  'path_dst': base_dir}
# Big_Query Destination -> Structure: Project_id.Dataset_id.Table_name_id
# Project name in Big Query 
project_id = 'mapsme-81e63'
# Dataset name in Big Query
dataset_id = 'appstore_connect_data'
# Credentials for Auth in GCP 
credentials_json = '..\\..\\credentials\\big_query_admin.json'

# %% [markdown]
# # Выгрузка

# %%
update = Reporter(**reporter_parms)

# %%
# print(update.show())
# Out:
# Типы отчетов ['SubscriptionEvent', 'Subscriber'], c 20240322 по 20240325, в директорию - C:\Users\PC\Desktop\Notebooks\datasets\Apple Appstore connect data

# %%
# subscribers = Reporter(**reporter_parms)
# subscribers.extract()

# %%
# reporter_parms['name'] = 'SubscriptionEvent'
# events = Reporter(**reporter_parms)
# events.extract()

# %%
# update.extract()

# %% [markdown]
# # Предобработка

# %%
all_filenames = os.listdir(base_dir)

# %%
#Вывести список файлов по пути base_dir
#all_filenames

# %% [markdown]
# # Preprocessing data

# %%
def check_csv(table):
    if (((table['Event_Date'] == ' ') | (table['Event_Date'].isnull())).sum() != 0):
        raise EmptyDate('Колонка с `Event Date` без даты')
    if (table["Standard_Subscription_Duration"].isnull().sum() != 0 ):
        raise EmptyString('Недостает значение в `Standard Subscription Duration`')

# %%
# %%time
dfs = {}
for file in all_filenames:
    path = os.path.join(base_dir,file)
    df = Preprocessing(path).get_data()
    try:
        check_csv(df)
    except:
        print(f'{file} сломан, предобработка не справилась с пропусками, поэтому загрузка невозможна')
        dfs.clear()
        break
    name_table = str(file[:-4:1].replace(r'_'+ str(appstore_id),'')[:-5:])
    if re.match(r'^(Subscriber|Subscription_Event)_202[3-9]\d{4}$', name_table):
        table_suffix = re.search('\d{8}',name_table).group(0)
        dfs.update(
                  {
                    name_table:
                    {'frame':df,
                     'table_suffix': table_suffix}
                   }
                  )
    else:
        print(f'По пути {path} неподходящее название файла')
# Out:
# CPU times: total: 15.6 ms
# Wall time: 195 ms

# %%
dfs
# Out:
# {'Subscriber_20240322': {'frame':     Event_Date                        App_Name  App_Apple_ID  \
#   0   2024-03-22  MAPS.ME: Offline Maps, GPS Nav     510623322
#   1   2024-03-22  MAPS.ME: Offline Maps, GPS Nav     510623322
#   2   2024-03-22  MAPS.ME: Offline Maps, GPS Nav     510623322
#   3   2024-03-22  MAPS.ME: Offline Maps, GPS Nav     510623322
#   4   2024-03-22  MAPS.ME: Offline Maps, GPS Nav     510623322
#   ..         ...                             ...           ...
#   642 2024-03-22  MAPS.ME: Offline Maps, GPS Nav     510623322
#   643 2024-03-23  MAPS.ME: Offline Maps, GPS Nav     510623322
#   644 2024-03-22  MAPS.ME: Offline Maps, GPS Nav     510623322
#   645 2024-03-22  MAPS.ME: Offline Maps, GPS Nav     510623322
#   646 2024-03-22  MAPS.ME: Offline Maps, GPS Nav     510623322
#
#                       Subscription_Name  Subscription_Apple_ID  \
#   0                       PRO 2 Monthly             6449304586
#   1                       PRO 2 Monthly             6449304586
#   2                       PRO 2 Monthly             6449304586
#   3                       PRO 1 Monthly             6449036918
#   4    Ads Monthly Holiday Sale Removal             1447378716
#   ..                                ...                    ...
#   642                      PRO 2 Annual             6449304178
#   643     Ads Yearly Discounted Removal             1449994089
#   644                     PRO 1 Monthly             6449036918
#   645                     PRO 2 Monthly             6449304586
#   646                      PRO 0 Annual             6445890346
#
#        Subscription_Group_ID Standard_Subscription_Duration  \
#   0                 21250831                        1 Month
#   1                 21250831                        1 Month
#   2                 21250831                        1 Month
#   3                 21250831                        1 Month
#   4                 20481970                        1 Month
#   ..                     ...                            ...
#   642               21250831                         1 Year
#   643               20481970                         1 Year
#   644               21250831                        1 Month
#   645               21250831                        1 Month
#   646               21250831                         1 Year
#
#        Subscription_Offer_Name  Promotional_Offer_ID Subscription_Offer_Type  \
#   0                        NaN                   NaN                     NaN
#   1                        NaN                   NaN                     NaN
#   2                        NaN                   NaN                     NaN
#   3                        NaN                   NaN                     NaN
#   4                        NaN                   NaN                     NaN
#   ..                       ...                   ...                     ...
#   642                      NaN                   NaN                     NaN
#   643                      NaN                   NaN                     NaN
#   644                      NaN                   NaN                     NaN
#   645                      NaN                   NaN                     NaN
#   646                      NaN                   NaN                     NaN
#
#        ... Preserved_Pricing      Proceeds_Reason  Client  Device  Country  \
#   0    ...               NaN                  NaN     NaN  iPhone       US
#   1    ...               NaN                  NaN     NaN  iPhone       CA
#   2    ...               NaN                  NaN     NaN  iPhone       CA
#   3    ...               NaN                  NaN     NaN  iPhone       AT
#   4    ...               NaN  Rate After One Year     NaN  iPhone       FR
#   ..   ...               ...                  ...     ...     ...      ...
#   642  ...               NaN                  NaN     NaN  iPhone       CA
#   643  ...               NaN  Rate After One Year     NaN  iPhone       CA
#   644  ...               NaN                  NaN     NaN  iPhone       KZ
#   645  ...               NaN                  NaN     NaN  iPhone       FR
#   646  ...               NaN                  NaN     NaN  iPhone       BY
#
#          Subscriber_ID  Subscriber_ID_Reset Refund  Purchase_Date Units
#   0    210587069211206                  NaN  False            NaN     1
#   1    525621387133180                  NaN  False            NaN     1
#   2    490571074071059                  NaN  False            NaN     1
#   3    420675395712665                  NaN  False            NaN     1
#   4    574563066656889                  NaN  False            NaN     1
#   ..               ...                  ...    ...            ...   ...
#   642  259710187114422                  NaN  False            NaN     1
#   643  154529084742139                  NaN  False            NaN     1
#   644  609608498561484                  NaN  False            NaN     1
#   645  539495557702201                  NaN  False            NaN     1
#   646  693483815358637                  NaN  False            NaN     1
#
#   [647 rows x 26 columns],
#   'table_suffix': '20240322'},
#  'Subscriber_20240323': {'frame':     Event_Date                        App_Name  App_Apple_ID  \
#   0   2024-03-23  MAPS.ME: Offline Maps, GPS Nav     510623322
#   1   2024-03-23  MAPS.ME: Offline Maps, GPS Nav     510623322
#   2   2024-03-23  MAPS.ME: Offline Maps, GPS Nav     510623322
#   3   2024-03-23  MAPS.ME: Offline Maps, GPS Nav     510623322
#   4   2024-03-23  MAPS.ME: Offline Maps, GPS Nav     510623322
#   ..         ...                             ...           ...
#   717 2024-03-24  MAPS.ME: Offline Maps, GPS Nav     510623322
#   718 2024-03-23  MAPS.ME: Offline Maps, GPS Nav     510623322
#   719 2024-03-23  MAPS.ME: Offline Maps, GPS Nav     510623322
#   720 2024-03-23  MAPS.ME: Offline Maps, GPS Nav     510623322
#   721 2024-03-23  MAPS.ME: Offline Maps, GPS Nav     510623322
#
#       Subscription_Name  Subscription_Apple_ID  Subscription_Group_ID  \
#   0       PRO 2 Monthly             6449304586               21250831
#   1        PRO 2 Annual             6449304178               21250831
#   2        PRO 0 Annual             6445890346               21250831
#   3       PRO 2 Monthly             6449304586               21250831
#   4       PRO 2 Monthly             6449304586               21250831
#   ..                ...                    ...                    ...
#   717     PRO 2 Monthly             6449304586               21250831
#   718      PRO 0 Annual             6445890346               21250831
#   719      PRO 0 Annual             6445890346               21250831
#   720      PRO 2 Annual             6449304178               21250831
#   721      PRO 1 Annual             6449036719               21250831
#
#       Standard_Subscription_Duration  Subscription_Offer_Name  \
#   0                          1 Month                      NaN
#   1                           1 Year                      NaN
#   2                           1 Year                      NaN
#   3                          1 Month                      NaN
#   4                          1 Month                      NaN
#   ..                             ...                      ...
#   717                        1 Month                      NaN
#   718                         1 Year                      NaN
#   719                         1 Year                      NaN
#   720                         1 Year                      NaN
#   721                         1 Year                      NaN
#
#        Promotional_Offer_ID Subscription_Offer_Type  ... Preserved_Pricing  \
#   0                     NaN                     NaN  ...               NaN
#   1                     NaN              Free Trial  ...               NaN
#   2                     NaN              Free Trial  ...               NaN
#   3                     NaN                     NaN  ...               NaN
#   4                     NaN                     NaN  ...               NaN
#   ..                    ...                     ...  ...               ...
#   717                   NaN                     NaN  ...               NaN
#   718                   NaN                     NaN  ...               NaN
#   719                   NaN              Free Trial  ...               NaN
#   720                   NaN              Free Trial  ...               NaN
#   721                   NaN                     NaN  ...               NaN
#
#        Proceeds_Reason  Client  Device  Country    Subscriber_ID  \
#   0                NaN     NaN  iPhone       US  434655323911076
#   1                NaN     NaN  iPhone       US  266670497105028
#   2                NaN     NaN  iPhone       KZ  462627970875975
#   3                NaN     NaN  iPhone       AM  182603848641062
#   4                NaN     NaN  iPhone       DE  658502090330436
#   ..               ...     ...     ...      ...              ...
#   717              NaN     NaN  iPhone       DE  252632649708469
#   718              NaN     NaN  iPhone       DE  490564164609619
#   719              NaN     NaN  iPhone       ES  161675659730657
#   720              NaN     NaN  iPhone       FR  497562259325441
#   721              NaN     NaN  iPhone       DE  490564164609619
#
#        Subscriber_ID_Reset Refund  Purchase_Date Units
#   0                    NaN  False            NaN     1
#   1                    NaN  False            NaN     1
#   2                    NaN  False            NaN     1
#   3                    NaN  False            NaN     1
#   4                    NaN  False            NaN     1
#   ..                   ...    ...            ...   ...
#   717                  NaN  False            NaN     1
#   718                  NaN  False            NaN     1
#   719                  NaN  False            NaN     1
#   720                  NaN  False            NaN     1
#   721                  NaN   True     2023-09-09     0
#
#   [722 rows x 26 columns],
#   'table_suffix': '20240323'},
#  'Subscriber_20240324': {'frame':     Event_Date                        App_Name  App_Apple_ID  \
#   0   2024-03-24  MAPS.ME: Offline Maps, GPS Nav     510623322
#   1   2024-03-24  MAPS.ME: Offline Maps, GPS Nav     510623322
#   2   2024-03-24  MAPS.ME: Offline Maps, GPS Nav     510623322
#   3   2024-03-24  MAPS.ME: Offline Maps, GPS Nav     510623322
#   4   2024-03-24  MAPS.ME: Offline Maps, GPS Nav     510623322
#   ..         ...                             ...           ...
#   737 2024-03-24  MAPS.ME: Offline Maps, GPS Nav     510623322
#   738 2024-03-24  MAPS.ME: Offline Maps, GPS Nav     510623322
#   739 2024-03-24  MAPS.ME: Offline Maps, GPS Nav     510623322
#   740 2024-03-24  MAPS.ME: Offline Maps, GPS Nav     510623322
#   741 2024-03-24  MAPS.ME: Offline Maps, GPS Nav     510623322
#
#       Subscription_Name  Subscription_Apple_ID  Subscription_Group_ID  \
#   0        PRO 2 Annual             6449304178               21250831
#   1        PRO 2 Annual             6449304178               21250831
#   2        PRO 2 Annual             6449304178               21250831
#   3       PRO 1 Monthly             6449036918               21250831
#   4       PRO 2 Monthly             6449304586               21250831
#   ..                ...                    ...                    ...
#   737     PRO 2 Monthly             6449304586               21250831
#   738      PRO 2 Annual             6449304178               21250831
#   739      PRO 2 Annual             6449304178               21250831
#   740      PRO 2 Annual             6449304178               21250831
#   741      PRO 2 Annual             6449304178               21250831
#
#       Standard_Subscription_Duration  Subscription_Offer_Name  \
#   0                           1 Year                      NaN
#   1                           1 Year                      NaN
#   2                           1 Year                      NaN
#   3                          1 Month                      NaN
#   4                          1 Month                      NaN
#   ..                             ...                      ...
#   737                        1 Month                      NaN
#   738                         1 Year                      NaN
#   739                         1 Year                      NaN
#   740                         1 Year                      NaN
#   741                         1 Year                      NaN
#
#        Promotional_Offer_ID Subscription_Offer_Type  ... Preserved_Pricing  \
#   0                     NaN              Free Trial  ...               NaN
#   1                     NaN              Free Trial  ...               NaN
#   2                     NaN              Free Trial  ...               NaN
#   3                     NaN                     NaN  ...               NaN
#   4                     NaN                     NaN  ...               NaN
#   ..                    ...                     ...  ...               ...
#   737                   NaN                     NaN  ...               NaN
#   738                   NaN                     NaN  ...               NaN
#   739                   NaN                     NaN  ...               NaN
#   740                   NaN              Free Trial  ...               NaN
#   741                   NaN              Free Trial  ...               NaN
#
#        Proceeds_Reason  Client  Device  Country    Subscriber_ID  \
#   0                NaN     NaN    iPad       US  770484083505719
#   1                NaN     NaN  iPhone       US  602613856321458
#   2                NaN     NaN  iPhone       KZ  784453177020081
#   3                NaN     NaN  iPhone       ES  189699082027583
#   4                NaN     NaN  iPhone       FR  238702361196000
#   ..               ...     ...     ...      ...              ...
#   737              NaN     NaN  iPhone       GB  259710419735622
#   738              NaN     NaN  iPhone       ES  679478263019250
#   739              NaN     NaN  iPhone       GB  686463827191830
#   740              NaN     NaN  iPhone       DE  518462547884654
#   741              NaN     NaN  iPhone       ES  189700383880695
#
#        Subscriber_ID_Reset Refund  Purchase_Date Units
#   0                    NaN  False            NaN     1
#   1                    NaN  False            NaN     1
#   2                    NaN  False            NaN     1
#   3                    NaN  False            NaN     1
#   4                    NaN  False            NaN     1
#   ..                   ...    ...            ...   ...
#   737                  NaN  False            NaN     1
#   738                  NaN  False            NaN     1
#   739                  NaN  False            NaN     1
#   740                  NaN  False            NaN     1
#   741                  NaN  False            NaN     1
#
#   [742 rows x 26 columns],
#   'table_suffix': '20240324'},
#  'Subscriber_20240325': {'frame':     Event_Date                        App_Name  App_Apple_ID  \
#   0   2024-03-25  MAPS.ME: Offline Maps, GPS Nav     510623322
#   1   2024-03-26  MAPS.ME: Offline Maps, GPS Nav     510623322
#   2   2024-03-25  MAPS.ME: Offline Maps, GPS Nav     510623322
#   3   2024-03-25  MAPS.ME: Offline Maps, GPS Nav     510623322
#   4   2024-03-25  MAPS.ME: Offline Maps, GPS Nav     510623322
#   ..         ...                             ...           ...
#   630 2024-03-25  MAPS.ME: Offline Maps, GPS Nav     510623322
#   631 2024-03-25  MAPS.ME: Offline Maps, GPS Nav     510623322
#   632 2024-03-26  MAPS.ME: Offline Maps, GPS Nav     510623322
#   633 2024-03-25  MAPS.ME: Offline Maps, GPS Nav     510623322
#   634 2024-03-25  MAPS.ME: Offline Maps, GPS Nav     510623322
#
#                    Subscription_Name  Subscription_Apple_ID  \
#   0                     PRO 2 Annual             6449304178
#   1                     PRO 2 Annual             6449304178
#   2                     PRO 1 Annual             6449036719
#   3    Ads Yearly Discounted Removal             1449994089
#   4    Ads Yearly Discounted Removal             1449994089
#   ..                             ...                    ...
#   630                   PRO 2 Annual             6449304178
#   631                  PRO 2 Monthly             6449304586
#   632                  PRO 1 Monthly             6449036918
#   633                  PRO 1 Monthly             6449036918
#   634                  PRO 2 Monthly             6449304586
#
#        Subscription_Group_ID Standard_Subscription_Duration  \
#   0                 21250831                         1 Year
#   1                 21250831                         1 Year
#   2                 21250831                         1 Year
#   3                 20481970                         1 Year
#   4                 20481970                         1 Year
#   ..                     ...                            ...
#   630               21250831                         1 Year
#   631               21250831                        1 Month
#   632               21250831                        1 Month
#   633               21250831                        1 Month
#   634               21250831                        1 Month
#
#        Subscription_Offer_Name  Promotional_Offer_ID Subscription_Offer_Type  \
#   0                        NaN                   NaN                     NaN
#   1                        NaN                   NaN                     NaN
#   2                        NaN                   NaN                     NaN
#   3                        NaN                   NaN                     NaN
#   4                        NaN                   NaN                     NaN
#   ..                       ...                   ...                     ...
#   630                      NaN                   NaN              Free Trial
#   631                      NaN                   NaN                     NaN
#   632                      NaN                   NaN                     NaN
#   633                      NaN                   NaN                     NaN
#   634                      NaN                   NaN                     NaN
#
#        ... Preserved_Pricing      Proceeds_Reason  Client  Device  Country  \
#   0    ...               NaN                  NaN     NaN  iPhone       US
#   1    ...               NaN                  NaN     NaN  iPhone       US
#   2    ...               NaN                  NaN     NaN  iPhone       DE
#   3    ...               NaN  Rate After One Year     NaN  iPhone       IT
#   4    ...               NaN  Rate After One Year     NaN  iPhone       RU
#   ..   ...               ...                  ...     ...     ...      ...
#   630  ...               NaN                  NaN     NaN  iPhone       US
#   631  ...               NaN                  NaN     NaN  iPhone       DE
#   632  ...               NaN                  NaN     NaN  iPhone       FR
#   633  ...               NaN                  NaN     NaN  iPhone       AU
#   634  ...               NaN                  NaN     NaN  iPhone       AU
#
#          Subscriber_ID  Subscriber_ID_Reset Refund  Purchase_Date Units
#   0    616610345919409                  NaN  False            NaN     1
#   1    266670497105028                  NaN  False            NaN     1
#   2    623560858761990                  NaN  False            NaN     1
#   3    217639063139731                  NaN  False            NaN     1
#   4    266610037895140                  NaN  False            NaN     1
#   ..               ...                  ...    ...            ...   ...
#   630  441670846973162                  NaN  False            NaN     1
#   631  574623325753696                  NaN  False            NaN     1
#   632  686459019531168                  NaN  False            NaN     1
#   633  672494224871359                  NaN  False            NaN     1
#   634  609606123931912                  NaN  False            NaN     1
#
#   [635 rows x 26 columns],
#   'table_suffix': '20240325'},
#  'Subscriber_20240326': {'frame':     Event_Date                        App_Name  App_Apple_ID  \
#   0   2024-03-27  MAPS.ME: Offline Maps, GPS Nav     510623322
#   1   2024-03-26  MAPS.ME: Offline Maps, GPS Nav     510623322
#   2   2024-03-26  MAPS.ME: Offline Maps, GPS Nav     510623322
#   3   2024-03-26  MAPS.ME: Offline Maps, GPS Nav     510623322
#   4   2024-03-26  MAPS.ME: Offline Maps, GPS Nav     510623322
#   ..         ...                             ...           ...
#   674 2024-03-26  MAPS.ME: Offline Maps, GPS Nav     510623322
#   675 2024-03-26  MAPS.ME: Offline Maps, GPS Nav     510623322
#   676 2024-03-26  MAPS.ME: Offline Maps, GPS Nav     510623322
#   677 2024-03-26  MAPS.ME: Offline Maps, GPS Nav     510623322
#   678 2024-03-26  MAPS.ME: Offline Maps, GPS Nav     510623322
#
#                       Subscription_Name  Subscription_Apple_ID  \
#   0                       PRO 2 Monthly             6449304586
#   1                       PRO 2 Monthly             6449304586
#   2    Ads Monthly Holiday Sale Removal             1447378716
#   3                       PRO 2 Monthly             6449304586
#   4                        PRO 1 Annual             6449036719
#   ..                                ...                    ...
#   674                      PRO 2 Annual             6449304178
#   675                      PRO 2 Annual             6449304178
#   676                      PRO 2 Annual             6449304178
#   677                      PRO 2 Annual             6449304178
#   678                     PRO 2 Monthly             6449304586
#
#        Subscription_Group_ID Standard_Subscription_Duration  \
#   0                 21250831                        1 Month
#   1                 21250831                        1 Month
#   2                 20481970                        1 Month
#   3                 21250831                        1 Month
#   4                 21250831                         1 Year
#   ..                     ...                            ...
#   674               21250831                         1 Year
#   675               21250831                         1 Year
#   676               21250831                         1 Year
#   677               21250831                         1 Year
#   678               21250831                        1 Month
#
#        Subscription_Offer_Name  Promotional_Offer_ID Subscription_Offer_Type  \
#   0                        NaN                   NaN                     NaN
#   1                        NaN                   NaN                     NaN
#   2                        NaN                   NaN                     NaN
#   3                        NaN                   NaN                     NaN
#   4                        NaN                   NaN              Free Trial
#   ..                       ...                   ...                     ...
#   674                      NaN                   NaN              Free Trial
#   675                      NaN                   NaN              Free Trial
#   676                      NaN                   NaN              Free Trial
#   677                      NaN                   NaN              Free Trial
#   678                      NaN                   NaN                     NaN
#
#        ... Preserved_Pricing      Proceeds_Reason  Client  Device  Country  \
#   0    ...               NaN                  NaN     NaN  iPhone       US
#   1    ...               NaN                  NaN     NaN  iPhone       BY
#   2    ...               NaN  Rate After One Year     NaN  iPhone       CH
#   3    ...               NaN                  NaN     NaN  iPhone       US
#   4    ...               NaN                  NaN     NaN  iPhone       CA
#   ..   ...               ...                  ...     ...     ...      ...
#   674  ...               NaN                  NaN     NaN  iPhone       US
#   675  ...               NaN                  NaN     NaN  iPhone       CA
#   676  ...               NaN                  NaN     NaN  iPhone       EC
#   677  ...               NaN                  NaN     NaN  iPhone       GB
#   678  ...               NaN                  NaN     NaN  iPhone       AU
#
#          Subscriber_ID  Subscriber_ID_Reset Refund  Purchase_Date Units
#   0    161670190189867                  NaN  False            NaN     1
#   1    553400728483780                  NaN  False            NaN     1
#   2    427541885021267                  NaN  False            NaN     1
#   3    427598770013242                  NaN  False            NaN     1
#   4    203672581406926                  NaN  False            NaN     1
#   ..               ...                  ...    ...            ...   ...
#   674  679478446172143                  NaN  False            NaN     1
#   675  441670879735885                  NaN  False            NaN     1
#   676  567630219151305                  NaN  False            NaN     1
#   677  497562386304839                  NaN  False            NaN     1
#   678  273679218532687                  NaN  False            NaN     1
#
#   [679 rows x 26 columns],
#   'table_suffix': '20240326'},
#  'Subscription_Event_20240322': {'frame':     Event_Date                                      Event  \
#   0   2024-03-22                                      Renew
#   1   2024-03-22                                     Refund
#   2   2024-03-23                                      Renew
#   3   2024-03-22                   Start Introductory Offer
#   4   2024-03-22                   Start Introductory Offer
#   ..         ...                                        ...
#   686 2024-03-22  Paid Subscription from Introductory Offer
#   687 2024-03-22                                      Renew
#   688 2024-03-22                                     Cancel
#   689 2024-03-22  Paid Subscription from Introductory Offer
#   690 2024-03-22                 Renewal from Billing Retry
#
#                              App_Name  App_Apple_ID Subscription_Name  \
#   0    MAPS.ME: Offline Maps, GPS Nav     510623322     PRO 2 Monthly
#   1    MAPS.ME: Offline Maps, GPS Nav     510623322      PRO 2 Annual
#   2    MAPS.ME: Offline Maps, GPS Nav     510623322     PRO 2 Monthly
#   3    MAPS.ME: Offline Maps, GPS Nav     510623322      PRO 2 Annual
#   4    MAPS.ME: Offline Maps, GPS Nav     510623322      PRO 1 Annual
#   ..                              ...           ...               ...
#   686  MAPS.ME: Offline Maps, GPS Nav     510623322      PRO 2 Annual
#   687  MAPS.ME: Offline Maps, GPS Nav     510623322     PRO 2 Monthly
#   688  MAPS.ME: Offline Maps, GPS Nav     510623322     PRO 2 Monthly
#   689  MAPS.ME: Offline Maps, GPS Nav     510623322      PRO 2 Annual
#   690  MAPS.ME: Offline Maps, GPS Nav     510623322      PRO 2 Annual
#
#        Subscription_Apple_ID  Subscription_Group_ID  \
#   0               6449304586               21250831
#   1               6449304178               21250831
#   2               6449304586               21250831
#   3               6449304178               21250831
#   4               6449036719               21250831
#   ..                     ...                    ...
#   686             6449304178               21250831
#   687             6449304586               21250831
#   688             6449304586               21250831
#   689             6449304178               21250831
#   690             6449304178               21250831
#
#       Standard_Subscription_Duration  Subscription_Offer_Name  \
#   0                          1 Month                      NaN
#   1                           1 Year                      NaN
#   2                          1 Month                      NaN
#   3                           1 Year                      NaN
#   4                           1 Year                      NaN
#   ..                             ...                      ...
#   686                         1 Year                      NaN
#   687                        1 Month                      NaN
#   688                        1 Month                      NaN
#   689                         1 Year                      NaN
#   690                         1 Year                      NaN
#
#        Promotional_Offer_ID  ...  Device State  Country  \
#   0                     NaN  ...  iPhone    AJ       GE
#   1                     NaN  ...  iPhone    NY       US
#   2                     NaN  ...  iPhone   NaN       CH
#   3                     NaN  ...  iPhone   茨城県       JP
#   4                     NaN  ...  iPhone    WA       US
#   ..                    ...  ...     ...   ...      ...
#   686                   NaN  ...  iPhone    ON       CA
#   687                   NaN  ...  iPhone   AAO       KZ
#   688                   NaN  ...  iPhone    AR       US
#   689                   NaN  ...  iPhone   NaN       FR
#   690                   NaN  ...  iPhone    BC       CA
#
#        Previous_Subscription_Name  Previous_Subscription_Apple_ID  \
#   0                           NaN                            <NA>
#   1                           NaN                            <NA>
#   2                           NaN                            <NA>
#   3                           NaN                            <NA>
#   4                           NaN                            <NA>
#   ..                          ...                             ...
#   686                         NaN                            <NA>
#   687                         NaN                            <NA>
#   688                         NaN                            <NA>
#   689                         NaN                            <NA>
#   690                         NaN                            <NA>
#
#       Days_Before_Canceling  Cancellation_Reason Days_Canceled Quantity  \
#   0                    <NA>                  NaN          <NA>        1
#   1                    <NA>             Canceled          <NA>        1
#   2                    <NA>                  NaN          <NA>        1
#   3                    <NA>                  NaN          <NA>        1
#   4                    <NA>                  NaN          <NA>        1
#   ..                    ...                  ...           ...      ...
#   686                  <NA>                  NaN          <NA>        1
#   687                  <NA>                  NaN          <NA>        1
#   688                    11             Canceled          <NA>        1
#   689                  <NA>                  NaN          <NA>        8
#   690                  <NA>                  NaN          <NA>        1
#
#       Paid_Service_Days_Recovered
#   0                           NaN
#   1                           NaN
#   2                           NaN
#   3                           NaN
#   4                           NaN
#   ..                          ...
#   686                         NaN
#   687                         NaN
#   688                         NaN
#   689                         NaN
#   690                         NaN
#
#   [691 rows x 29 columns],
#   'table_suffix': '20240322'},
#  'Subscription_Event_20240323': {'frame':     Event_Date                                      Event  \
#   0   2024-03-24                                      Renew
#   1   2024-03-23  Paid Subscription from Introductory Offer
#   2   2024-03-23                   Start Introductory Offer
#   3   2024-03-23                                     Cancel
#   4   2024-03-23                                     Cancel
#   ..         ...                                        ...
#   679 2024-03-23                Canceled from Billing Retry
#   680 2024-03-23                Canceled from Billing Retry
#   681 2024-03-23  Paid Subscription from Introductory Offer
#   682 2024-03-23                                     Cancel
#   683 2024-03-23                   Start Introductory Offer
#
#                              App_Name  App_Apple_ID Subscription_Name  \
#   0    MAPS.ME: Offline Maps, GPS Nav     510623322     PRO 2 Monthly
#   1    MAPS.ME: Offline Maps, GPS Nav     510623322      PRO 1 Annual
#   2    MAPS.ME: Offline Maps, GPS Nav     510623322      PRO 2 Annual
#   3    MAPS.ME: Offline Maps, GPS Nav     510623322      PRO 2 Annual
#   4    MAPS.ME: Offline Maps, GPS Nav     510623322     PRO 2 Monthly
#   ..                              ...           ...               ...
#   679  MAPS.ME: Offline Maps, GPS Nav     510623322      PRO 2 Annual
#   680  MAPS.ME: Offline Maps, GPS Nav     510623322      PRO 1 Annual
#   681  MAPS.ME: Offline Maps, GPS Nav     510623322      PRO 1 Annual
#   682  MAPS.ME: Offline Maps, GPS Nav     510623322     PRO 2 Monthly
#   683  MAPS.ME: Offline Maps, GPS Nav     510623322      PRO 2 Annual
#
#        Subscription_Apple_ID  Subscription_Group_ID  \
#   0               6449304586               21250831
#   1               6449036719               21250831
#   2               6449304178               21250831
#   3               6449304178               21250831
#   4               6449304586               21250831
#   ..                     ...                    ...
#   679             6449304178               21250831
#   680             6449036719               21250831
#   681             6449036719               21250831
#   682             6449304586               21250831
#   683             6449304178               21250831
#
#       Standard_Subscription_Duration  Subscription_Offer_Name  \
#   0                          1 Month                      NaN
#   1                           1 Year                      NaN
#   2                           1 Year                      NaN
#   3                           1 Year                      NaN
#   4                          1 Month                      NaN
#   ..                             ...                      ...
#   679                         1 Year                      NaN
#   680                         1 Year                      NaN
#   681                         1 Year                      NaN
#   682                        1 Month                      NaN
#   683                         1 Year                      NaN
#
#        Promotional_Offer_ID  ...  Device State  Country  \
#   0                     NaN  ...  iPhone   QLD       AU
#   1                     NaN  ...  iPhone    VA       US
#   2                     NaN  ...  iPhone    ME       US
#   3                     NaN  ...  iPhone   NaN       CZ
#   4                     NaN  ...  iPhone   NaN       FR
#   ..                    ...  ...     ...   ...      ...
#   679                   NaN  ...  iPhone    FL       US
#   680                   NaN  ...  iPhone    NY       US
#   681                   NaN  ...  iPhone    FL       US
#   682                   NaN  ...  iPhone   NaN       BY
#   683                   NaN  ...  iPhone   TAS       AU
#
#        Previous_Subscription_Name  Previous_Subscription_Apple_ID  \
#   0                           NaN                            <NA>
#   1                           NaN                            <NA>
#   2                           NaN                            <NA>
#   3                           NaN                            <NA>
#   4                           NaN                            <NA>
#   ..                          ...                             ...
#   679                         NaN                            <NA>
#   680                         NaN                            <NA>
#   681                         NaN                            <NA>
#   682                         NaN                            <NA>
#   683                         NaN                            <NA>
#
#       Days_Before_Canceling  Cancellation_Reason Days_Canceled Quantity  \
#   0                    <NA>                  NaN          <NA>        1
#   1                    <NA>                  NaN          <NA>        1
#   2                    <NA>                  NaN          <NA>        1
#   3                       1             Canceled          <NA>        1
#   4                      62             Canceled          <NA>        3
#   ..                    ...                  ...           ...      ...
#   679                  <NA>        Billing issue          <NA>        2
#   680                  <NA>        Billing issue          <NA>        3
#   681                  <NA>                  NaN          <NA>        1
#   682                    25             Canceled          <NA>        1
#   683                  <NA>                  NaN          <NA>        1
#
#       Paid_Service_Days_Recovered
#   0                           NaN
#   1                           NaN
#   2                           NaN
#   3                           NaN
#   4                           NaN
#   ..                          ...
#   679                         NaN
#   680                         NaN
#   681                         NaN
#   682                         NaN
#   683                         NaN
#
#   [684 rows x 29 columns],
#   'table_suffix': '20240323'},
#  'Subscription_Event_20240324': {'frame':     Event_Date                        Event                        App_Name  \
#   0   2024-03-24                    Subscribe  MAPS.ME: Offline Maps, GPS Nav
#   1   2024-03-25                       Cancel  MAPS.ME: Offline Maps, GPS Nav
#   2   2024-03-24                        Renew  MAPS.ME: Offline Maps, GPS Nav
#   3   2024-03-24                       Cancel  MAPS.ME: Offline Maps, GPS Nav
#   4   2024-03-24     Start Introductory Offer  MAPS.ME: Offline Maps, GPS Nav
#   ..         ...                          ...                             ...
#   658 2024-03-24                    Subscribe  MAPS.ME: Offline Maps, GPS Nav
#   659 2024-03-24                    Subscribe  MAPS.ME: Offline Maps, GPS Nav
#   660 2024-03-24  Canceled from Billing Retry  MAPS.ME: Offline Maps, GPS Nav
#   661 2024-03-24                        Renew  MAPS.ME: Offline Maps, GPS Nav
#   662 2024-03-24                        Renew  MAPS.ME: Offline Maps, GPS Nav
#
#        App_Apple_ID              Subscription_Name  Subscription_Apple_ID  \
#   0       510623322                  PRO 2 Monthly             6449304586
#   1       510623322                  PRO 2 Monthly             6449304586
#   2       510623322                  PRO 2 Monthly             6449304586
#   3       510623322  Discounted Yearly Ads Removal             1449994089
#   4       510623322                   PRO 2 Annual             6449304178
#   ..            ...                            ...                    ...
#   658     510623322                  PRO 2 Monthly             6449304586
#   659     510623322                  PRO 1 Monthly             6449036918
#   660     510623322                   PRO 2 Annual             6449304178
#   661     510623322                  PRO 1 Monthly             6449036918
#   662     510623322                  PRO 2 Monthly             6449304586
#
#        Subscription_Group_ID Standard_Subscription_Duration  \
#   0                 21250831                        1 Month
#   1                 21250831                        1 Month
#   2                 21250831                        1 Month
#   3                 20481970                         1 Year
#   4                 21250831                         1 Year
#   ..                     ...                            ...
#   658               21250831                        1 Month
#   659               21250831                        1 Month
#   660               21250831                         1 Year
#   661               21250831                        1 Month
#   662               21250831                        1 Month
#
#        Subscription_Offer_Name  Promotional_Offer_ID  ...  Device State  \
#   0                        NaN                   NaN  ...  iPhone    QC
#   1                        NaN                   NaN  ...  iPhone   QLD
#   2                        NaN                   NaN  ...  iPhone    RI
#   3                        NaN                   NaN  ...  iPhone   NaN
#   4                        NaN                   NaN  ...  iPhone   NaN
#   ..                       ...                   ...  ...     ...   ...
#   658                      NaN                   NaN  ...  iPhone     B
#   659                      NaN                   NaN  ...  iPhone    BC
#   660                      NaN                   NaN  ...    iPad    NC
#   661                      NaN                   NaN  ...  iPhone    PM
#   662                      NaN                   NaN  ...  iPhone   ATY
#
#        Country  Previous_Subscription_Name  Previous_Subscription_Apple_ID  \
#   0         CA                         NaN                            <NA>
#   1         AU                         NaN                            <NA>
#   2         US                         NaN                            <NA>
#   3         DE                         NaN                            <NA>
#   4         AM                         NaN                            <NA>
#   ..       ...                         ...                             ...
#   658       ES                         NaN                            <NA>
#   659       CA                         NaN                            <NA>
#   660       US                         NaN                            <NA>
#   661       ES                         NaN                            <NA>
#   662       KZ                         NaN                            <NA>
#
#       Days_Before_Canceling  Cancellation_Reason Days_Canceled Quantity  \
#   0                    <NA>                  NaN          <NA>        2
#   1                      31             Canceled          <NA>        1
#   2                    <NA>                  NaN          <NA>        1
#   3                    1631             Canceled          <NA>        1
#   4                    <NA>                  NaN          <NA>        1
#   ..                    ...                  ...           ...      ...
#   658                  <NA>                  NaN          <NA>        1
#   659                  <NA>                  NaN          <NA>        1
#   660                  <NA>        Billing issue          <NA>        1
#   661                  <NA>                  NaN          <NA>        1
#   662                  <NA>                  NaN          <NA>        1
#
#       Paid_Service_Days_Recovered
#   0                           NaN
#   1                           NaN
#   2                           NaN
#   3                           NaN
#   4                           NaN
#   ..                          ...
#   658                         NaN
#   659                         NaN
#   660                         NaN
#   661                         NaN
#   662                         NaN
#
#   [663 rows x 29 columns],
#   'table_suffix': '20240324'},
#  'Subscription_Event_20240325': {'frame':     Event_Date                        Event                        App_Name  \
#   0   2024-03-25                        Renew  MAPS.ME: Offline Maps, GPS Nav
#   1   2024-03-25                       Cancel  MAPS.ME: Offline Maps, GPS Nav
#   2   2024-03-25                        Renew  MAPS.ME: Offline Maps, GPS Nav
#   3   2024-03-25     Start Introductory Offer  MAPS.ME: Offline Maps, GPS Nav
#   4   2024-03-25  Canceled from Billing Retry  MAPS.ME: Offline Maps, GPS Nav
#   ..         ...                          ...                             ...
#   652 2024-03-25     Start Introductory Offer  MAPS.ME: Offline Maps, GPS Nav
#   653 2024-03-25   Renewal from Billing Retry  MAPS.ME: Offline Maps, GPS Nav
#   654 2024-03-26     Start Introductory Offer  MAPS.ME: Offline Maps, GPS Nav
#   655 2024-03-25                       Cancel  MAPS.ME: Offline Maps, GPS Nav
#   656 2024-03-25     Start Introductory Offer  MAPS.ME: Offline Maps, GPS Nav
#
#        App_Apple_ID Subscription_Name  Subscription_Apple_ID  \
#   0       510623322     PRO 2 Monthly             6449304586
#   1       510623322      PRO 2 Annual             6449304178
#   2       510623322     PRO 2 Monthly             6449304586
#   3       510623322      PRO 2 Annual             6449304178
#   4       510623322      PRO 1 Annual             6449036719
#   ..            ...               ...                    ...
#   652     510623322      PRO 1 Annual             6449036719
#   653     510623322      PRO 2 Annual             6449304178
#   654     510623322      PRO 2 Annual             6449304178
#   655     510623322      PRO 2 Annual             6449304178
#   656     510623322      PRO 2 Annual             6449304178
#
#        Subscription_Group_ID Standard_Subscription_Duration  \
#   0                 21250831                        1 Month
#   1                 21250831                         1 Year
#   2                 21250831                        1 Month
#   3                 21250831                         1 Year
#   4                 21250831                         1 Year
#   ..                     ...                            ...
#   652               21250831                         1 Year
#   653               21250831                         1 Year
#   654               21250831                         1 Year
#   655               21250831                         1 Year
#   656               21250831                         1 Year
#
#        Subscription_Offer_Name  Promotional_Offer_ID  ...  Device State  \
#   0                        NaN                   NaN  ...  iPhone   NaN
#   1                        NaN                   NaN  ...  iPhone   福岡県
#   2                        NaN                   NaN  ...  iPhone    MN
#   3                        NaN                   NaN  ...    iPad    CA
#   4                        NaN                   NaN  ...  iPhone    AK
#   ..                       ...                   ...  ...     ...   ...
#   652                      NaN                   NaN  ...  iPhone   NaN
#   653                      NaN                   NaN  ...  iPhone   AAO
#   654                      NaN                   NaN  ...  iPhone   LEY
#   655                      NaN                   NaN  ...  iPhone    IL
#   656                      NaN                   NaN  ...  iPhone    NV
#
#        Country  Previous_Subscription_Name  Previous_Subscription_Apple_ID  \
#   0         GB                         NaN                            <NA>
#   1         JP                         NaN                            <NA>
#   2         US                         NaN                            <NA>
#   3         US                         NaN                            <NA>
#   4         US                         NaN                            <NA>
#   ..       ...                         ...                             ...
#   652       DE                         NaN                            <NA>
#   653       KZ                         NaN                            <NA>
#   654       PH                         NaN                            <NA>
#   655       US                         NaN                            <NA>
#   656       US                         NaN                            <NA>
#
#       Days_Before_Canceling  Cancellation_Reason Days_Canceled Quantity  \
#   0                    <NA>                  NaN          <NA>        2
#   1                       0             Canceled          <NA>        1
#   2                    <NA>                  NaN          <NA>        1
#   3                    <NA>                  NaN          <NA>        1
#   4                    <NA>        Billing issue          <NA>        3
#   ..                    ...                  ...           ...      ...
#   652                  <NA>                  NaN          <NA>        7
#   653                  <NA>                  NaN          <NA>        1
#   654                  <NA>                  NaN          <NA>        1
#   655                     0             Canceled          <NA>        1
#   656                  <NA>                  NaN          <NA>        1
#
#       Paid_Service_Days_Recovered
#   0                           NaN
#   1                           NaN
#   2                           NaN
#   3                           NaN
#   4                           NaN
#   ..                          ...
#   652                         NaN
#   653                         NaN
#   654                         NaN
#   655                         NaN
#   656                         NaN
#
#   [657 rows x 29 columns],
#   'table_suffix': '20240325'},
#  'Subscription_Event_20240326': {'frame':     Event_Date                                      Event  \
#   0   2024-03-27                                     Cancel
#   1   2024-03-27                 Renewal from Billing Retry
#   2   2024-03-27  Paid Subscription from Introductory Offer
#   3   2024-03-27                                      Renew
#   4   2024-03-27                   Start Introductory Offer
#   ..         ...                                        ...
#   701 2024-03-26                                     Cancel
#   702 2024-03-26                                      Renew
#   703 2024-03-26                   Start Introductory Offer
#   704 2024-03-26                 Renewal from Billing Retry
#   705 2024-03-26                                  Subscribe
#
#                              App_Name  App_Apple_ID  \
#   0    MAPS.ME: Offline Maps, GPS Nav     510623322
#   1    MAPS.ME: Offline Maps, GPS Nav     510623322
#   2    MAPS.ME: Offline Maps, GPS Nav     510623322
#   3    MAPS.ME: Offline Maps, GPS Nav     510623322
#   4    MAPS.ME: Offline Maps, GPS Nav     510623322
#   ..                              ...           ...
#   701  MAPS.ME: Offline Maps, GPS Nav     510623322
#   702  MAPS.ME: Offline Maps, GPS Nav     510623322
#   703  MAPS.ME: Offline Maps, GPS Nav     510623322
#   704  MAPS.ME: Offline Maps, GPS Nav     510623322
#   705  MAPS.ME: Offline Maps, GPS Nav     510623322
#
#                       Subscription_Name  Subscription_Apple_ID  \
#   0                        PRO 2 Annual             6449304178
#   1                       PRO 2 Monthly             6449304586
#   2                        PRO 1 Annual             6449036719
#   3                       PRO 1 Monthly             6449036918
#   4                        PRO 2 Annual             6449304178
#   ..                                ...                    ...
#   701                     PRO 2 Monthly             6449304586
#   702  Ads Monthly Holiday Sale Removal             1447378716
#   703                      PRO 2 Annual             6449304178
#   704                     PRO 1 Monthly             6449036918
#   705                     PRO 1 Monthly             6449036918
#
#        Subscription_Group_ID Standard_Subscription_Duration  \
#   0                 21250831                         1 Year
#   1                 21250831                        1 Month
#   2                 21250831                         1 Year
#   3                 21250831                        1 Month
#   4                 21250831                         1 Year
#   ..                     ...                            ...
#   701               21250831                        1 Month
#   702               20481970                        1 Month
#   703               21250831                         1 Year
#   704               21250831                        1 Month
#   705               21250831                        1 Month
#
#        Subscription_Offer_Name  Promotional_Offer_ID  ...  Device State  \
#   0                        NaN                   NaN  ...  iPhone   石川県
#   1                        NaN                   NaN  ...  iPhone   NaN
#   2                        NaN                   NaN  ...  iPhone     1
#   3                        NaN                   NaN  ...  iPhone   NaN
#   4                        NaN                   NaN  ...  iPhone   大阪府
#   ..                       ...                   ...  ...     ...   ...
#   701                      NaN                   NaN  ...  iPhone     8
#   702                      NaN                   NaN  ...  iPhone    LA
#   703                      NaN                   NaN  ...  iPhone    CO
#   704                      NaN                   NaN  ...  iPhone   NaN
#   705                      NaN                   NaN  ...  iPhone   NaN
#
#        Country  Previous_Subscription_Name  Previous_Subscription_Apple_ID  \
#   0         JP                         NaN                            <NA>
#   1         CH                         NaN                            <NA>
#   2         IS                         NaN                            <NA>
#   3         FR                         NaN                            <NA>
#   4         JP                         NaN                            <NA>
#   ..       ...                         ...                             ...
#   701       IS                         NaN                            <NA>
#   702       US                         NaN                            <NA>
#   703       US                         NaN                            <NA>
#   704       FR                         NaN                            <NA>
#   705       BY                         NaN                            <NA>
#
#       Days_Before_Canceling  Cancellation_Reason Days_Canceled Quantity  \
#   0                       0             Canceled          <NA>        1
#   1                    <NA>                  NaN          <NA>        1
#   2                    <NA>                  NaN          <NA>        1
#   3                    <NA>                  NaN          <NA>        1
#   4                    <NA>                  NaN          <NA>        1
#   ..                    ...                  ...           ...      ...
#   701                    97             Canceled          <NA>        1
#   702                  <NA>                  NaN          <NA>        1
#   703                  <NA>                  NaN          <NA>        1
#   704                  <NA>                  NaN          <NA>        1
#   705                  <NA>                  NaN          <NA>        1
#
#       Paid_Service_Days_Recovered
#   0                           NaN
#   1                           NaN
#   2                           NaN
#   3                           NaN
#   4                           NaN
#   ..                          ...
#   701                         NaN
#   702                         NaN
#   703                         NaN
#   704                         NaN
#   705                         NaN
#
#   [706 rows x 29 columns],
#   'table_suffix': '20240326'}}

# %% [markdown]
# # Load data to BigQuery

# %% [markdown]
# ## Connect

# %%
from google.oauth2.service_account import Credentials
from google.cloud import bigquery as bq

# %%
load_config_parms = {
                     'autodetect': True,
                     'create_disposition':'CREATE_IF_NEEDED',
                     'destination_table_description' : 'Data load by @dki script'
                    }

# %%
# 1
job_config = bq.LoadJobConfig(**load_config_parms)
credentials = Credentials.from_service_account_file(credentials_json) # создание объекта с кредо
client = bq.Client(credentials=credentials,
                   project=project_id,
                   default_load_job_config=job_config)
# 2
subscriber_schema = client.schema_from_json('schema/subscriber.json')
subcription_event_schema = client.schema_from_json('schema/subcription_event.json')

# %%
from datetime import datetime
# Последний Table_suffix
query_job = client.query(f''' 
SELECT ANY_VALUE (_TABLE_SUFFIX HAVING MAX PARSE_DATE('%Y%m%d', _TABLE_SUFFIX) ) AS last_date 
FROM  `{dataset_id}.Subscriber_*`
UNION ALL 
SELECT ANY_VALUE (_TABLE_SUFFIX HAVING MAX PARSE_DATE('%Y%m%d', _TABLE_SUFFIX) ) AS last_date 
FROM  `{dataset_id}.Subscription_Event_*`''')
try:
    dates = query_job.to_dataframe().rename(index={0:'Subscriber_*',1:'Subscription_Event_*'})
    print(dates)
    dates_dict = {'Subscriber':dates.loc['Subscriber_*','last_date'],
                 'Subscription_Event': dates.loc['Subscription_Event_*','last_date']}
except exceptions.BadRequest as exc:
    print(exc)

# %% [markdown]
# ## Load

# %%
def is_there_in_wildcards(name_table,table_suffix):
    """
    name_table, 
    table_suffix

    
    """
    if(re.match('^Subscriber.+', name_table)):
        if datetime.strptime(table_suffix,'%Y%m%d')  <= datetime.strptime(dates_dict['Subscriber'],'%Y%m%d'):
                print(f'{name_table} имеет table_suffix раньше крайней даты, что есть среди BQ Wildcards')
                return False
        return True
    elif (re.match('^Subscription.+',name_table)):
        if datetime.strptime(table_suffix,'%Y%m%d') <= datetime.strptime(dates_dict['Subscription_Event'],'%Y%m%d'):
                print(f'{name_table} имеет table_suffix раньше крайней даты, что есть среди BQ Wildcards')
                return False
        return True
    else:
        print(f'{name_table} не подходит под формат `Subscriber_...` или `Subscription_Event_...`')
        return False
    
jobs = []



for name_table,data in dfs.items():
    if re.match('^Subscription_Event.+', name_table):
        job_config.schema = subcription_event_schema
    else:
        job_config.schema = subscriber_schema
    job = client.load_table_from_dataframe(dataframe=data['frame'],
                                          destination=f'{project_id}.{dataset_id}.{name_table}',
                                          job_config=job_config)

# %% [markdown]
# # Result

# %%
help(client)

# %%
# Последний Table_suffix
query_job = client.query(f''' 
SELECT 
    table_suffix_date,
    DATE_DIFF(table_suffix_date, LAG(table_suffix_date) OVER (ORDER BY table_suffix_date), DAY) as date_diff
FROM (
    SELECT 
DISTINCT PARSE_DATE('%Y%m%d', _TABLE_SUFFIX) AS table_suffix_date
FROM  `{dataset_id}.Subscription_Event_*`)
''')

# %%
all_tables = query_job.to_dataframe()

# %%
more_one_day = all_tables['date_diff'] > 1
all_tables[more_one_day]['table_suffix_date']
